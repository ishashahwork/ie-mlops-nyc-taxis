# %% [markdown]
# ## Scenario 1: A single data scientist participating in an ML competition
#
# This scenario demonstrates how an individual data scientist can use MLflow to track machine learning experiments on their local machine. This is a common setup for solo projects, hackathons, or competitions where collaboration and remote access are not required.
#
# ### MLflow setup overview
# - **Tracking server:** Not used (runs locally, no remote server)
# - **Backend store:** Local filesystem (stores experiment metadata in the `mlruns/` folder)
# - **Artifacts store:** Local filesystem (stores model files and other artifacts in the same `mlruns/` folder)
#
# With this setup, all experiment runs, parameters, metrics, and artifacts are saved locally. You can explore and compare your experiments using the MLflow UI.
#
# ### How to use the MLflow UI
# - You can launch the MLflow UI by running `mlflow ui` in your terminal, or by running the provided code cell in this notebook.
# - The UI will be available at [http://localhost:5000](http://localhost:5000).
# - Use the UI to browse experiments, compare runs, and inspect logged models and artifacts.
#
# > **Tip:** This local setup is ideal for learning and prototyping. For team projects or production, you would typically use a remote tracking server and a more robust backend (e.g., a database and cloud storage).

# %%
# %pip install mlflow
import mlflow
# Out:
# Collecting mlflow
#   Using cached mlflow-3.1.4-py3-none-any.whl (24.7 MB)
# Collecting Flask<4
#   Downloading flask-3.1.3-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 5.3 MB/s eta 0:00:01
# Collecting pyarrow<21,>=4.0.0
#   Downloading pyarrow-20.0.0-cp39-cp39-macosx_12_0_arm64.whl (30.8 MB)
#      |████████████████████████████████| 30.8 MB 14.1 MB/s eta 0:00:01
# Collecting graphene<4
#   Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#      |████████████████████████████████| 114 kB 32.8 MB/s eta 0:00:01
# Collecting matplotlib<4
#   Using cached matplotlib-3.9.4-cp39-cp39-macosx_11_0_arm64.whl (7.8 MB)
# Collecting alembic!=1.10.0,<2
#   Downloading alembic-1.16.5-py3-none-any.whl (247 kB)
#      |████████████████████████████████| 247 kB 13.2 MB/s eta 0:00:01
# Collecting scikit-learn<2
#   Using cached scikit_learn-1.6.1-cp39-cp39-macosx_12_0_arm64.whl (11.1 MB)
# Collecting pandas<3
#   Using cached pandas-2.3.3-cp39-cp39-macosx_11_0_arm64.whl (10.8 MB)
# Collecting scipy<2
#   Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
#      |████████████████████████████████| 30.3 MB 18.6 MB/s eta 0:00:01     |█████████████████████████▉      | 24.5 MB 11.1 MB/s eta 0:00:01
# Collecting docker<8,>=4.0.0
#   Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 14.4 MB/s eta 0:00:01
# Collecting numpy<3
#   Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
# Collecting mlflow-skinny==3.1.4
#   Downloading mlflow_skinny-3.1.4-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 23.8 MB/s eta 0:00:01
# Collecting sqlalchemy<3,>=1.4.0
#   Downloading sqlalchemy-2.0.48-cp39-cp39-macosx_11_0_arm64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 17.8 MB/s eta 0:00:01
# Collecting gunicorn<24
#   Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 16.4 MB/s eta 0:00:01
# Collecting packaging<26
#   Downloading packaging-25.0-py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 37.9 MB/s  eta 0:00:01
# Collecting databricks-sdk<1,>=0.20.0
#   Downloading databricks_sdk-0.96.0-py3-none-any.whl (813 kB)
#      |████████████████████████████████| 813 kB 18.5 MB/s eta 0:00:01
# Collecting pydantic<3,>=1.10.8
#   Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
#      |████████████████████████████████| 463 kB 29.6 MB/s eta 0:00:01
# Collecting fastapi<1
#   Using cached fastapi-0.128.8-py3-none-any.whl (103 kB)
# Collecting cachetools<7,>=5.0.0
#   Downloading cachetools-6.2.6-py3-none-any.whl (11 kB)
# Collecting gitpython<4,>=3.1.9
#   Downloading gitpython-3.1.46-py3-none-any.whl (208 kB)
#      |████████████████████████████████| 208 kB 21.6 MB/s eta 0:00:01
# Collecting pyyaml<7,>=5.1
#   Using cached pyyaml-6.0.3-cp39-cp39-macosx_11_0_arm64.whl (174 kB)
# Collecting sqlparse<1,>=0.4.0
#   Downloading sqlparse-0.5.5-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 18.7 MB/s eta 0:00:01
# Collecting click<9,>=7.0
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 57.3 MB/s  eta 0:00:01
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /Users/ishashah/Downloads/ie-mlops-nyc-taxis/.venv/lib/python3.9/site-packages (from mlflow-skinny==3.1.4->mlflow) (4.15.0)
# Collecting uvicorn<1
#   Using cached uvicorn-0.39.0-py3-none-any.whl (68 kB)
# Collecting cloudpickle<4
#   Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Collecting opentelemetry-api<3,>=1.9.0
#   Downloading opentelemetry_api-1.39.1-py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 21.5 MB/s eta 0:00:01
# Collecting opentelemetry-sdk<3,>=1.9.0
#   Downloading opentelemetry_sdk-1.39.1-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 77.0 MB/s eta 0:00:01
# Collecting protobuf<7,>=3.12.0
#   Downloading protobuf-6.33.5-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
#      |████████████████████████████████| 427 kB 53.9 MB/s eta 0:00:01
# Collecting requests<3,>=2.17.3
#   Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /Users/ishashah/Downloads/ie-mlops-nyc-taxis/.venv/lib/python3.9/site-packages (from mlflow-skinny==3.1.4->mlflow) (8.7.1)
# Collecting tomli
#   Using cached tomli-2.4.0-py3-none-any.whl (14 kB)
# Collecting Mako
#   Downloading mako-1.3.10-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 22.7 MB/s eta 0:00:01
# Collecting google-auth~=2.0
#   Downloading google_auth-2.48.0-py3-none-any.whl (236 kB)
#      |████████████████████████████████| 236 kB 39.2 MB/s eta 0:00:01
# Collecting urllib3>=1.26.0
#   Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Collecting typing-inspection>=0.4.2
#   Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Collecting annotated-doc>=0.0.2
#   Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Collecting starlette<1.0.0,>=0.40.0
#   Downloading starlette-0.49.3-py3-none-any.whl (74 kB)
#      |████████████████████████████████| 74 kB 13.6 MB/s eta 0:00:01
# Collecting werkzeug>=3.1.0
#   Downloading werkzeug-3.1.6-py3-none-any.whl (225 kB)
#      |████████████████████████████████| 225 kB 5.5 MB/s eta 0:00:01
# Collecting itsdangerous>=2.2.0
#   Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Collecting jinja2>=3.1.2
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Collecting markupsafe>=2.1.1
#   Using cached markupsafe-3.0.3-cp39-cp39-macosx_11_0_arm64.whl (12 kB)
# Collecting blinker>=1.9.0
#   Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 8.6 MB/s  eta 0:00:01
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Collecting cryptography>=38.0.3
#   Downloading cryptography-46.0.5-cp38-abi3-macosx_10_9_universal2.whl (7.2 MB)
#      |████████████████████████████████| 7.2 MB 7.8 MB/s eta 0:00:01
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 10.8 MB/s eta 0:00:01
# Collecting cffi>=2.0.0
#   Using cached cffi-2.0.0-cp39-cp39-macosx_11_0_arm64.whl (180 kB)
# Collecting pycparser
#   Using cached pycparser-2.23-py3-none-any.whl (118 kB)
# Collecting graphql-relay<3.3,>=3.1
#   Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /Users/ishashah/Downloads/ie-mlops-nyc-taxis/.venv/lib/python3.9/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Collecting graphql-core<3.3,>=3.1
#   Downloading graphql_core-3.2.7-py3-none-any.whl (207 kB)
#      |████████████████████████████████| 207 kB 16.4 MB/s eta 0:00:01
# Requirement already satisfied: zipp>=3.20 in /Users/ishashah/Downloads/ie-mlops-nyc-taxis/.venv/lib/python3.9/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.1.4->mlflow) (3.23.0)
# Collecting pillow>=8
#   Downloading pillow-11.3.0-cp39-cp39-macosx_11_0_arm64.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 38.3 MB/s eta 0:00:01
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp39-cp39-macosx_11_0_arm64.whl (249 kB)
#      |████████████████████████████████| 249 kB 28.4 MB/s eta 0:00:01
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#      |████████████████████████████████| 122 kB 12.4 MB/s eta 0:00:01
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp39-cp39-macosx_11_0_arm64.whl (64 kB)
#      |████████████████████████████████| 64 kB 16.5 MB/s eta 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.60.2-cp39-cp39-macosx_10_9_universal2.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 9.5 MB/s eta 0:00:01
# Collecting opentelemetry-semantic-conventions==0.60b1
#   Downloading opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl (219 kB)
#      |████████████████████████████████| 219 kB 10.3 MB/s eta 0:00:01
# Collecting pytz>=2020.1
#   Downloading pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 13.0 MB/s eta 0:00:01
# Collecting tzdata>=2022.7
#   Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Collecting pyasn1<0.7.0,>=0.6.1
#   Downloading pyasn1-0.6.2-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 10.9 MB/s eta 0:00:01
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.41.5
#   Downloading pydantic_core-2.41.5-cp39-cp39-macosx_11_0_arm64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 11.2 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /Users/ishashah/Downloads/ie-mlops-nyc-taxis/.venv/lib/python3.9/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Collecting charset_normalizer<4,>=2
#   Using cached charset_normalizer-3.4.4-cp39-cp39-macosx_10_9_universal2.whl (209 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.11-py3-none-any.whl (71 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
#      |████████████████████████████████| 153 kB 9.4 MB/s eta 0:00:01
# Collecting joblib>=1.2.0
#   Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
#      |████████████████████████████████| 309 kB 18.9 MB/s eta 0:00:01
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting anyio<5,>=3.6.2
#   Using cached anyio-4.12.1-py3-none-any.whl (113 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/ishashah/Downloads/ie-mlops-nyc-taxis/.venv/lib/python3.9/site-packages (from anyio<5,>=3.6.2->starlette<1.0.0,>=0.40.0->fastapi<1->mlflow-skinny==3.1.4->mlflow) (1.3.1)
# Collecting h11>=0.8
#   Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: pycparser, pyasn1, idna, cffi, urllib3, typing-inspection, smmap, rsa, pydantic-core, pyasn1-modules, opentelemetry-api, cryptography, charset-normalizer, certifi, anyio, annotated-types, starlette, requests, pydantic, protobuf, opentelemetry-semantic-conventions, numpy, markupsafe, h11, graphql-core, google-auth, gitdb, click, annotated-doc, werkzeug, uvicorn, tzdata, tomli, threadpoolctl, sqlparse, sqlalchemy, scipy, pyyaml, pytz, pyparsing, pillow, packaging, opentelemetry-sdk, Mako, kiwisolver, joblib, jinja2, itsdangerous, importlib-resources, graphql-relay, gitpython, fonttools, fastapi, databricks-sdk, cycler, contourpy, cloudpickle, cachetools, blinker, scikit-learn, pyarrow, pandas, mlflow-skinny, matplotlib, gunicorn, graphene, Flask, docker, alembic, mlflow
#   Attempting uninstall: packaging
#     Found existing installation: packaging 26.0
#     Uninstalling packaging-26.0:
#       Successfully uninstalled packaging-26.0
# Successfully installed Flask-3.1.3 Mako-1.3.10 alembic-1.16.5 annotated-doc-0.0.4 annotated-types-0.7.0 anyio-4.12.1 blinker-1.9.0 cachetools-6.2.6 certifi-2026.2.25 cffi-2.0.0 charset-normalizer-3.4.4 click-8.1.8 cloudpickle-3.1.2 contourpy-1.3.0 cryptography-46.0.5 cycler-0.12.1 databricks-sdk-0.96.0 docker-7.1.0 fastapi-0.128.8 fonttools-4.60.2 gitdb-4.0.12 gitpython-3.1.46 google-auth-2.48.0 graphene-3.4.3 graphql-core-3.2.7 graphql-relay-3.2.0 gunicorn-23.0.0 h11-0.16.0 idna-3.11 importlib-resources-6.5.2 itsdangerous-2.2.0 jinja2-3.1.6 joblib-1.5.3 kiwisolver-1.4.7 markupsafe-3.0.3 matplotlib-3.9.4 mlflow-3.1.4 mlflow-skinny-3.1.4 numpy-2.0.2 opentelemetry-api-1.39.1 opentelemetry-sdk-1.39.1 opentelemetry-semantic-conventions-0.60b1 packaging-25.0 pandas-2.3.3 pillow-11.3.0 protobuf-6.33.5 pyarrow-20.0.0 pyasn1-0.6.2 pyasn1-modules-0.4.2 pycparser-2.23 pydantic-2.12.5 pydantic-core-2.41.5 pyparsing-3.3.2 pytz-2026.1.post1 pyyaml-6.0.3 requests-2.32.5 rsa-4.9.1 scikit-learn-1.6.1 scipy-1.13.1 smmap-5.0.2 sqlalchemy-2.0.48 sqlparse-0.5.5 starlette-0.49.3 threadpoolctl-3.6.0 tomli-2.4.0 typing-inspection-0.4.2 tzdata-2025.3 urllib3-2.6.3 uvicorn-0.39.0 werkzeug-3.1.6
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/ishashah/Downloads/ie-mlops-nyc-taxis/.venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# /Users/ishashah/Downloads/ie-mlops-nyc-taxis/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'file:///Users/ishashah/Downloads/ie-mlops-nyc-taxis/03-experiment-tracking/mlruns'

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='file:///Users/ishashah/Downloads/ie-mlops-nyc-taxis/03-experiment-tracking/mlruns/0', creation_time=1772554879485, experiment_id='0', last_update_time=1772554879485, lifecycle_stage='active', name='Default', tags={}>]

# %% [markdown]
# ### Creating an experiment and logging a new run

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score, confusion_matrix
import numpy as np
import mlflow
import sklearn
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

mlflow.set_experiment("my-experiment-1")

X, y = load_iris(return_X_y=True)
class_names = load_iris().target_names

models = [
    ("LogisticRegression", LogisticRegression(C=1.0, random_state=42, max_iter=1000, solver="lbfgs")),
    ("RandomForestClassifier", RandomForestClassifier(n_estimators=100, random_state=42))
]

for model_name, model in models:
    with mlflow.start_run() as run:
        mlflow.set_tag("model_type", model_name)
        mlflow.log_param("sklearn_version", sklearn.__version__)
        model.fit(X, y)
        y_pred = model.predict(X)
        acc = accuracy_score(y, y_pred)
        mlflow.log_metric("accuracy", acc)
        # Log confusion matrix as labeled DataFrame
        cm = confusion_matrix(y, y_pred)
        cm_df = pd.DataFrame(cm, index=class_names, columns=class_names)
        cm_df.to_csv("confusion_matrix_labeled.csv")
        mlflow.log_artifact("confusion_matrix_labeled.csv")
        # Confusion matrix heatmap as image
        plt.figure(figsize=(5,4))
        sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues")
        plt.title(f"Confusion Matrix ({model_name})")
        plt.ylabel("True label")
        plt.xlabel("Predicted label")
        plt.tight_layout()
        plt.savefig("confusion_matrix_heatmap.png")
        plt.close()
        mlflow.log_artifact("confusion_matrix_heatmap.png")
        # Provide input_example and use 'name' instead of deprecated 'artifact_path'
        input_example = np.expand_dims(X[0], axis=0)
        mlflow.sklearn.log_model(model, name="models", input_example=input_example)
        mlflow.set_tag("n_classes", len(np.unique(y)))
        mlflow.set_tag("run_time", datetime.datetime.now().isoformat())
        mlflow.set_tag("description", f"{model_name} on Iris dataset")
        print(f"Logged run for {model_name}, accuracy={acc:.3f}")
# Out:
# 2026/03/03 17:22:24 INFO mlflow.tracking.fluent: Experiment with name 'my-experiment-1' does not exist. Creating a new experiment.
# Logged run for LogisticRegression, accuracy=0.973
# Logged run for RandomForestClassifier, accuracy=1.000

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='file:///Users/ishashah/Downloads/ie-mlops-nyc-taxis/03-experiment-tracking/mlruns/110825882831007287', creation_time=1772554944421, experiment_id='110825882831007287', last_update_time=1772554944421, lifecycle_stage='active', name='my-experiment-1', tags={}>,
#  <Experiment: artifact_location='file:///Users/ishashah/Downloads/ie-mlops-nyc-taxis/03-experiment-tracking/mlruns/0', creation_time=1772554879485, experiment_id='0', last_update_time=1772554879485, lifecycle_stage='active', name='Default', tags={}>]

# %%
# Launch MLflow UI (default: uses local mlruns/ folder)
import subprocess
import sys

# This will run 'mlflow ui' as a background process
subprocess.Popen([sys.executable, '-m', 'mlflow', 'ui'])
print("MLflow UI started. Open http://localhost:5000 in your browser.")
# Out:
# MLflow UI started. Open http://localhost:5000 in your browser.
# /Users/ishashah/Downloads/ie-mlops-nyc-taxis/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# [2026-03-03 17:22:35 +0100] [73899] [INFO] Starting gunicorn 23.0.0
# [2026-03-03 17:22:35 +0100] [73899] [INFO] Listening at: http://127.0.0.1:5000 (73899)
# [2026-03-03 17:22:35 +0100] [73899] [INFO] Using worker: sync
# [2026-03-03 17:22:35 +0100] [73900] [INFO] Booting worker with pid: 73900
# [2026-03-03 17:22:35 +0100] [73901] [INFO] Booting worker with pid: 73901
# [2026-03-03 17:22:35 +0100] [73902] [INFO] Booting worker with pid: 73902
# /Users/ishashah/Downloads/ie-mlops-nyc-taxis/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# [2026-03-03 17:22:35 +0100] [73903] [INFO] Booting worker with pid: 73903
# /Users/ishashah/Downloads/ie-mlops-nyc-taxis/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/ishashah/Downloads/ie-mlops-nyc-taxis/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/ishashah/Downloads/ie-mlops-nyc-taxis/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ### Interacting with the model registry

# %%
from mlflow.tracking import MlflowClient


client = MlflowClient()

# %%
from mlflow.exceptions import MlflowException

try:
    client.search_registered_models()
except MlflowException:
    print("It's not possible to access the model registry :(")
